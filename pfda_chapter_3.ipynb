# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import randn

# %matplotlib inline

# %%
a = 5
a
# Out:
# 5

# %%
data = {i : randn() for i in range(7)}
data
# Out:
# {0: -1.6151052924013898,
#  1: -1.4612821935594211,
#  2: -0.338946402538556,
#  3: -1.8260947275716406,
#  4: -0.09717535162605465,
#  5: 0.4696961433724676,
#  6: 0.6731450384580937}

# %%
an_apple = 27

# %%
an_example = 42

# %%
an_apple
# Out:
# 27

# %%
b = [1, 2, 3]

# %%
b.append(4)

# %%
b
# Out:
# [1, 2, 3, 4]

# %%
import datetime

# %%
b?

# %%
def add_numbers(a, b):
    '''Add two numbers together
    
    Returns
    -------
    the_sum : type of arguments
    '''
    return a + b

# %%
# Get help
add_numbers?

# %%
# Show source code
add_numbers??

# %%
# Searching with a wildcard
np.*load*?

# %%
# %run ipython_script_test.py

# %%
c
# Out:
# 7.5

# %%
result
# Out:
# 1.4666666666666666

# %%
cats = 40
dogs = 12
all_animals = 94.0

# %%
# %run -i ipython_script_test.py

# %%
f(cats, dogs, all_animals)
# Out:
# 0.5531914893617021

# %%
x = 5
y = 7
if x > 5:
    x += 1
    y = 8

# %%
a = np.random.randn(100, 100)

# %%
# %timeit np.dot(a, a)
# Out:
# The slowest run took 98.93 times longer than the fastest. This could mean that an intermediate result is being cached
# 10000 loops, best of 3: 97.3 µs per loop

# %%
# Delete a variable
% xdel a
a
# Out:
# NameError: name 'a' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-b98128962376> in <module>()
#       1 get_ipython().magic(u'xdel a')
# ----> 2 a
#
# NameError: name 'a' is not defined

# %%
# %matplotlib
img = plt.imread('Melbourne sights small.png')
imshow(img)
# Out:
# Using matplotlib backend: MacOSX
